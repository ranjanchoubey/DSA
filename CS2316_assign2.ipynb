# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjanchoubey/DSA/blob/master/CS2316_assign2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("hi")
# Out:
# hi
